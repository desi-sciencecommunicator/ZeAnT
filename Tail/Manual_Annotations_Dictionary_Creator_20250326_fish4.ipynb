# %% [markdown]
# ### Manual Annotations Dictionary Creator
# Generating the dictionary pickle file that will be used for visualizations in the other manual annotation notebooks
#
# Desiderio Ascencio
# September 1, 2026
# California Institute of Technology

# %%
import os, pickle
import numpy as np

# %%
# USER INPUTTED PARAMATERS

home_dir = '/Users/desi/Desktop/caltech_mac/cmpk2/'
fish_label = '20250326_fish4'

# %%
print('home_dir path: {0}'.format(home_dir))
print('home_dir path exists: {0}'.format(os.path.isdir(home_dir)))
print('{0}'.format('-'*(len(home_dir)+len(' path: ')))) #cosmetic line,

flick_dict_fname = os.path.join(home_dir, '{0}_manual_annotations.pickle'.format(fish_label))
# Out:
# home_dir path: /Users/desi/Desktop/caltech_mac/cmpk2/
# home_dir path exists: True
# ---------------------------------------------

# %%
tail_flicks_dict = {

'600-900': {'fin': np.array([818]),
            'normal':np.array([657, 742, 819]),
            'strong':np.array([605, 628, 677, 700, 741, 743, 753, 817, 848])
                        },

'900-1200': {'fin': np.array([946, 985, 1033, 1052, 1119, 1170, 1171, 1188 ]), 
            'normal':np.array([902, 982, 1005, 1034, 1086, 1107, 1108, 1169, 1186]), 
            'strong':np.array([903, 939, 945, 992, 1041, 1051, 1082, 1122, 1149, 1184, 1185])
            }, 

'1200-1800': {'fin': np.array([1231, 1237, 1278, 1283, 1286, 1287, 1443, 1547, 1661, 1733, 1778]), 
            'normal':np.array([1281, 1381, 1384, 1492, 1549, 1600, 1693, 1787]),
            'strong':np.array([1230, 1235, 1280, 1289, 1330, 1383, 1413, 1442, 1476, 1496, 1507, 1508, 1520, 1559, 1616, 1617, 1618, 1659, 1670, 1698, 1703, 1715, 1716, 1737, 1738, 1747, 1777, 1786, 1795])
            }, 

'1800-2280': {'fin': np.array([1898, 1899, 1920, 1963, 2014, 2028, 2046, 2050, 2059, 2113, 2121, 2148, 2149, 2169]), 
            'normal':np.array([1814, 1876, 1903, 1969, 2008, 2012, 2020, 2039, 2087, 2166, 2178]), 
            'strong':np.array([1835, 1869, 1901, 1918, 1919, 1927, 1961, 1999, 2023, 2024, 2042, 2057, 2062, 2067, 2088, 2101, 2102, 2118, 2129, 2145, 2153, 2156, 2198, 2207, 2208, 2220, 2231])
            }, 

'2280-2400': {'fin': np.array([2399]), 
            'normal':np.array([2301, 2343, 2385]),
            'strong':np.array([2307, 2345, 2387])
            }, 
}

# %%
try: 
    with open(flick_dict_fname, 'wb') as f:
        pickle.dump(tail_flicks_dict, f, protocol=pickle.HIGHEST_PROTOCOL)
        f.close()
    print('Saved the dictionary to {0}'.format(flick_dict_fname))
except:
    print('Something went wrong trying to save to {0}'.format(flick_dict_fname))
# Out:
# Saved the dictionary to /Users/desi/Desktop/caltech_mac/cmpk2/20250326_fish4_manual_annotations.pickle
