# %% [markdown]
# ### Manual Annotations Dictionary Creator
# Generating the dictionary pickle file that will be used for visualizations in the other manual annotation notebooks
#
# Desiderio Ascencio
# September 1, 2026
# California Institute of Technology

# %%
import os, pickle
import numpy as np

# %%
# USER INPUTTED PARAMATERS

home_dir = '/Users/desi/Desktop/caltech_mac/cmpk2/'
fish_label = '20250326_fish2'

# %%
print('home_dir path: {0}'.format(home_dir))
print('home_dir path exists: {0}'.format(os.path.isdir(home_dir)))
print('{0}'.format('-'*(len(home_dir)+len(' path: ')))) #cosmetic line,

flick_dict_fname = os.path.join(home_dir, '{0}_manual_annotations.pickle'.format(fish_label))
# Out:
# home_dir path: /Users/desi/Desktop/caltech_mac/cmpk2/
# home_dir path exists: True
# ---------------------------------------------

# %%
tail_flicks_dict = {

'600-900': {'fin': np.array([646]),
            'normal':np.array([739, 783]),
            'strong':np.array([693, 792, 798, 840, 842, 843, 847, 851, 852, 853, 856, 860, 890])
                        },

'900-1200': {'fin': np.array([1118, 1191]), 
            'normal':np.array([920, 963, 964, 995, 1022, 1085, 1086, 1116, 1192, 1197]), 
            'strong':np.array([970, 1034, 1042, 1058, 1087, 1089, 1122, 1178])
            }, 

'1200-1800': {'fin': np.array([1312, 1457, 1502, 1629, 1680, 1690, 1732, 1735]), 
            'normal':np.array([1227, 1328, 1397, 1493, 1500, 1508, 1509, 1512, 1577, 1579, 1645, 
                               1646, 1648, 1649, 1685, 1686, 1688, 1690, 1728, 1741, 1769, 1783, 
                               1787, 1788]),
            'strong':np.array([1200,1329, 1336, 1428, 1653, 1742])
            }, 

'1800-2280': {'fin': np.array([1980, 2039, 2068, 2075, 2100, 2110, 2217, 2251]), 
            'normal':np.array([1844, 1863, 1888, 1919, 1930, 1933, 1949, 1998, 2005, 2043, 2076, 
                               2136, 2139, 2158, 2159, 2170, 2200, 2207, 2228, 2240, 2241, 2242, 
                               2243, 2257, 2258, 2262, 2279]), 
            'strong':np.array([1864, 1931, 2001, 2071, 2160, 2167, 2260])
            }, 

'2280-2400': {'fin': np.array([2283, 2379, 2387, 2391, 2395]), 
            'normal':np.array([2287, 2291, 2295, 2299, 2303, 2307, 2310, 2315, 2319, 2323, 2327, 
                               2328, 2331, 2333, 2335, 2339, 2343, 2347, 2349, 2351, 2355, 2359, 
                               2362, 2363, 2364, 2367, 2371, 2375, 2378]),
            'strong':np.array([2383])
            }, 

}

# %%
try: 
    with open(flick_dict_fname, 'wb') as f:
        pickle.dump(tail_flicks_dict, f, protocol=pickle.HIGHEST_PROTOCOL)
        f.close()
    print('Saved the dictionary to {0}'.format(flick_dict_fname))
except:
    print('Something went wrong trying to save to {0}'.format(flick_dict_fname))
# Out:
# Saved the dictionary to /Users/desi/Desktop/caltech_mac/cmpk2/20250326_fish2_manual_annotations.pickle
