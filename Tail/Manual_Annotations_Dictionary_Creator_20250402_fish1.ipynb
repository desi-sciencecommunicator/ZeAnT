# %% [markdown]
# ### Manual Annotations Dictionary Creator
# Generating the dictionary pickle file that will be used for visualizations in the other manual annotation notebooks
#
# Desiderio Ascencio
# September 1, 2026
# California Institute of Technology

# %%
import os, pickle
import numpy as np

# %%
# USER INPUTTED PARAMATERS

home_dir = '/Users/desi/Desktop/caltech_mac/cmpk2/'
fish_label = '20250402_fish1'

# %%
print('home_dir path: {0}'.format(home_dir))
print('home_dir path exists: {0}'.format(os.path.isdir(home_dir)))
print('{0}'.format('-'*(len(home_dir)+len(' path: ')))) #cosmetic line,

flick_dict_fname = os.path.join(home_dir, '{0}_manual_annotations.pickle'.format(fish_label))
# Out:
# home_dir path: /Users/desi/Desktop/caltech_mac/cmpk2/
# home_dir path exists: True
# ---------------------------------------------

# %%
tail_flicks_dict = {

'600-900': {'fin': np.array([684, 875, 877]),
            'normal':np.array([641, 653, 654, 655, 793, 876]),
            'strong':np.array([695])
                        },

'900-1200': {'fin': np.array([ 911, 912, 973, 974, 975, 1090, 1091, 1124]), 
            'normal':np.array([913, 972, 980, 1033, 1034, 1122, 1123]), 
            'strong':np.array([1138])
            }, 

'1200-1800': {'fin': np.array([1207, 1210, 1211, 1212, 1310, 1311, 1313]), 
            'normal':np.array([1206, 1285, 1286, 1309, 1312, 1315, 1378, 1379, 1426, 1427, 1428, 1429, 1457, 1459, 1427, 1428, 1429, 1457, 1459, 1474, 1476, 1518, 1697, 1698, 1699, 1727, 1767, 1768, 1770, 1787, 1788]),
            'strong':np.array([1529])
            }, 

'1800-2280': {'fin': np.array([1828, 1839, 1855, 1950, 2007, 2094, 2134, 2238]), 
            'normal':np.array([1829, 1838, 1853, 1854, 1863, 1903, 1943, 1948, 1949, 2040, 2045, 2133, 2196, 2205, 2206, 2235]), 
            'strong':np.array([1827, 1864, 2006, 2093, 2132, 2236])
            }, 

'2280-2400': {'fin': np.array([2338]), 
            'normal':np.array([2315, 2318, 2327, 2337]),
            'strong':np.array([2290])
            }, 
}

# %%
try: 
    with open(flick_dict_fname, 'wb') as f:
        pickle.dump(tail_flicks_dict, f, protocol=pickle.HIGHEST_PROTOCOL)
        f.close()
    print('Saved the dictionary to {0}'.format(flick_dict_fname))
except:
    print('Something went wrong trying to save to {0}'.format(flick_dict_fname))
# Out:
# Saved the dictionary to /Users/desi/Desktop/caltech_mac/cmpk2/20250402_fish1_manual_annotations.pickle
