# %% [markdown]
# ### Manual Annotations Dictionary Creator
# Generating the dictionary pickle file that will be used for visualizations in the other manual annotation notebooks
#
# Desiderio Ascencio
# September 1, 2026
# California Institute of Technology

# %%
import os, pickle
import numpy as np

# %%
# USER INPUTTED PARAMATERS

home_dir = '/Users/desi/Desktop/caltech_mac/cmpk2/'
fish_label = '20250326_fish3'

# %%
print('home_dir path: {0}'.format(home_dir))
print('home_dir path exists: {0}'.format(os.path.isdir(home_dir)))
print('{0}'.format('-'*(len(home_dir)+len(' path: ')))) #cosmetic line,

flick_dict_fname = os.path.join(home_dir, '{0}_manual_annotations.pickle'.format(fish_label))
# Out:
# home_dir path: /Users/desi/Desktop/caltech_mac/cmpk2/
# home_dir path exists: True
# ---------------------------------------------

# %%
tail_flicks_dict = {

'600-900': {'fin': np.array([]),
            'normal':np.array([601, 623, 631, 635, 638, 726, 740, 754, 759, 760, 761, 822, 826, 827, 896]),
            'strong':np.array([611, 636, 639, 762, 828, 898])
                        },

'900-1200': {'fin': np.array([1194]), 
            'normal':np.array([940, 944, 949, 1022, 1064, 1138, 1140, 1144, 1198]), 
            'strong':np.array([945, 947, 1023, 1071, 1074, 1141, 11423, 1199])
            }, 

'1200-1800': {'fin': np.array([1327]), 
            'normal':np.array([1233, 1253, 1264, 1270, 1284, 1311, 1318, 1326, 1365, 1375, 1376, 1388, 1399, 1409, 1411, 1470, 1480, 1483, 1458, 1506, 1537, 1585, 1611, 1616, 1617, 1628, 1655, 1717, 1727, 1728, 1794]),
            'strong':np.array([1200, 1205, 1268, 1269, 1330, 1378, 1412, 1483, 1484, 1541, 1618, 1658, 1661, 1703, 1731])
            }, 

'1800-2280': {'fin': np.array([1919, 2159]), 
            'normal':np.array([1083, 1877, 1886, 1931, 1997, 2039, 2088, 2152, 2172, 2222, 2249, 2261]), 
            'strong':np.array([1804, 1805, 1885, 1887, 1933, 2004, 2090, 2173, 2253, 2254, 2255])
            }, 

'2280-2400': {'fin': np.array([2318, 2327]), 
            'normal':np.array([]),
            'strong':np.array([2339, 2349, 2351, 2352, 2353, 2359])
            }, 
}

# %%
try: 
    with open(flick_dict_fname, 'wb') as f:
        pickle.dump(tail_flicks_dict, f, protocol=pickle.HIGHEST_PROTOCOL)
        f.close()
    print('Saved the dictionary to {0}'.format(flick_dict_fname))
except:
    print('Something went wrong trying to save to {0}'.format(flick_dict_fname))
# Out:
# Saved the dictionary to /Users/desi/Desktop/caltech_mac/cmpk2/20250326_fish3_manual_annotations.pickle
